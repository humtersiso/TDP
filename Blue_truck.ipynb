# %% [markdown]
# ## 車隊管理

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from datetime import datetime

# %%
    db_test_string1 = 'postgresql://postgres:transiot@52.69.32.193:5432/tms_log'
    db_test_string2 = 'postgresql://postgres:transiot@52.69.32.193:5432/tms_data'
    tms_test_log = create_engine(db_test_string1, pool_size=10, max_overflow=20)
    tms_test_data = create_engine(db_test_string2, pool_size=10, max_overflow=20) #測試機
    
    db_string1 = 'postgresql://postgres:RDSiot@192.168.1.252:5432/tms_log'
    db_string2 = 'postgresql://postgres:RDSiot@192.168.1.252:5432/tms_data'
    tms_log = create_engine(db_string1, pool_size=10, max_overflow=20)
    tms_data = create_engine(db_string2, pool_size=10, max_overflow=20) #正式機

# %% [markdown]
# #### 貨車 vehicle_is='000CBF14989B' '8CDE52B20531'

# %%
    user = pd.read_sql( "SELECT vehicle_id, event_time, total_mileage,\
    event_lon, event_lat, speed,battery_voltage, ua_time, ud_time from raw_data_temp_joe where event_time between '2018-10-01'\
    and '2018-11-10' \
    and vehicle_id in('8CDE52B20531','000CBF14989B') ", tms_test_log)

# %%
user[user['event_time']>'2018-11-05']
# Out:
#         vehicle_id          event_time  total_mileage   event_lon  event_lat  \
# 4269  8CDE52B20531 2018-11-05 08:57:37         0.0000  121.433160  24.986582
# 4270  8CDE52B20531 2018-11-05 08:57:52         0.0000  121.433200  24.986603
# 4271  8CDE52B20531 2018-11-05 08:58:07         0.0000  121.433210  24.986616
# 4272  8CDE52B20531 2018-11-05 08:58:22         0.0000  121.433174  24.986658
# 4273  8CDE52B20531 2018-11-05 08:58:37         0.0000  121.433170  24.986654
# 4274  8CDE52B20531 2018-11-05 08:58:52         0.0000  121.433160  24.986597
# 4275  8CDE52B20531 2018-11-05 08:59:08         0.0000  121.433140  24.986593
# 4276  8CDE52B20531 2018-11-05 08:59:23        11.1111  121.433040  24.986647
# 4277  8CDE52B20531 2018-11-05 08:59:38        15.0000  121.432990  24.986704
# 4278  8CDE52B20531 2018-11-05 08:59:53        98.0556  121.433240  24.987345
# 4279  8CDE52B20531 2018-11-05 09:00:09        73.0556  121.433400  24.987936
# ...

# %%
    trip = pd.read_sql( "SELECT * FROM risk_mag where start_time > '2018-10-01' and vehicle_id in('8CDE52B20531','000CBF14989B') ", tms_test_log)

# %%
trip[trip['start_time']>'2018-11-02']
# Out:
#        id    vehicle_id          start_time            end_time       mileage  \
# 36  32007  8CDE52B20531 2018-11-02 07:37:39 2018-11-02 10:00:29  58831.667120
# 37  32104  8CDE52B20531 2018-11-02 10:09:53 2018-11-02 11:14:47  41591.666745
# 38  32164  8CDE52B20531 2018-11-02 11:52:43 2018-11-02 12:15:28  17487.777752
# 39  32284  8CDE52B20531 2018-11-02 15:06:57 2018-11-02 15:28:42   5371.666629
# 40  32305  8CDE52B20531 2018-11-02 15:31:36 2018-11-02 15:31:50      0.000000
# 41  32225  8CDE52B20531 2018-11-02 13:10:28 2018-11-02 13:48:13  23263.055198
# 42  32265  8CDE52B20531 2018-11-02 14:30:21 2018-11-02 15:01:09  18303.333204
# 43  32306  8CDE52B20531 2018-11-02 15:39:32 2018-11-02 16:39:17  39018.055350
# 44  34703  8CDE52B20531 2018-11-05 10:24:47                 NaT  29205.277905
# 45  34646  8CDE52B20531 2018-11-05 08:57:23 2018-11-05 09:38:23  41710.555181
#
#     avg_speed_sum  ua_time  ud_time  speeding_sum  data_count    ...      \
# ...

# %%
trip[trip['vehicle_id']=='000CBF14989B']
# Out:
#        id    vehicle_id          start_time            end_time       mileage  \
# 0   29664  000CBF14989B 2018-10-30 17:03:20 2018-10-30 17:17:35   4950.833304
# 1   29623  000CBF14989B 2018-10-30 16:28:09 2018-10-30 16:42:24   1136.944444
# 2   30141  000CBF14989B 2018-10-31 08:34:34 2018-10-31 08:53:34   8614.444564
# 3   30041  000CBF14989B 2018-10-31 06:30:18 2018-10-31 06:40:18   4129.999964
# 4   30084  000CBF14989B 2018-10-31 07:32:41 2018-10-31 08:24:56  50759.444325
# 5   30161  000CBF14989B 2018-10-31 08:59:52 2018-10-31 09:00:21      9.444445
# 6   30162  000CBF14989B 2018-10-31 09:20:29 2018-10-31 09:41:32  10633.888675
# 7   30181  000CBF14989B 2018-10-31 09:46:20 2018-10-31 09:47:20     31.666665
# 8   30201  000CBF14989B 2018-10-31 10:17:32 2018-10-31 10:30:31  16047.222010
# 9   30221  000CBF14989B 2018-10-31 10:40:46 2018-10-31 11:12:12  22959.444119
# 10  30241  000CBF14989B 2018-10-31 11:25:52 2018-10-31 12:03:38  30763.055682
# ...

# %%
trip[['start_time','end_time','ua_time','ud_time','speeding','risk_score']]
# Out:
#            start_time            end_time  ua_time  ud_time   speeding  \
# 0 2018-11-01 18:03:39 2018-11-01 18:06:24        0        0   0.000000
# 1 2018-11-02 07:37:39 2018-11-02 10:00:29       28       33  35.599998
# 2 2018-11-02 10:09:53 2018-11-02 11:14:47       20       22  29.266670
# 3 2018-11-02 11:52:43 2018-11-02 12:15:28        1        1   0.000000
# 4 2018-11-02 13:10:28 2018-11-02 13:48:13        1        1   0.466667
# 5 2018-11-02 14:30:21                 NaT        1        1   0.000000
#
#    risk_score
# 0         5.0
# 1        65.0
# 2        75.0
# 3        30.0
# 4        35.0
# 5         0.0

# %% [markdown]
# ## END
